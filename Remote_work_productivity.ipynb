# %%
import  pandas as pd

# %%
df = pd.read_csv('/content/Extended_Employee_Performance_and_Productivity_Data.csv')
df
# Out:
#        Employee_ID        Department  Gender  Age   Job_Title  \
# 0                1                IT    Male   55  Specialist
# 1                2           Finance    Male   29   Developer
# 2                3           Finance    Male   55  Specialist
# 3                4  Customer Support  Female   48     Analyst
# 4                5       Engineering  Female   36     Analyst
# ...            ...               ...     ...  ...         ...
# 99995        99996           Finance    Male   27  Technician
# 99996        99997                IT  Female   36  Consultant
# 99997        99998        Operations    Male   53     Analyst
# 99998        99999                HR  Female   22  Consultant
# 99999       100000           Finance  Female   43     Analyst
#
#                         Hire_Date  Years_At_Company Education_Level  \
# 0      2022-01-19 08:03:05.556036                 2     High School
# 1      2024-04-18 08:03:05.556036                 0     High School
# ...

# %%
df = df.drop(['Employee_ID','Department','Gender','Job_Title','Hire_Date','Sick_Days','Team_Size','Employee_Satisfaction_Score','Resigned'],axis=1)
df = df.dropna()
df
# Out:
#        Age  Years_At_Company Education_Level  Performance_Score  \
# 0       55                 2     High School                  5
# 1       29                 0     High School                  5
# 2       55                 8     High School                  3
# 3       48                 7        Bachelor                  2
# 4       36                 3        Bachelor                  2
# ...    ...               ...             ...                ...
# 99995   27                 1        Bachelor                  4
# 99996   36                 6          Master                  5
# 99997   53                 8     High School                  2
# 99998   22                 9     High School                  5
# 99999   43                 0             PhD                  1
#
#        Monthly_Salary  Work_Hours_Per_Week  Projects_Handled  Overtime_Hours  \
# 0              6750.0                   33                32              22
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Education_Level'] = le.fit_transform(df['Education_Level'])
df
# Out:
#        Age  Years_At_Company  Education_Level  Performance_Score  \
# 0       55                 2                1                  5
# 1       29                 0                1                  5
# 2       55                 8                1                  3
# 3       48                 7                0                  2
# 4       36                 3                0                  2
# ...    ...               ...              ...                ...
# 99995   27                 1                0                  4
# 99996   36                 6                2                  5
# 99997   53                 8                1                  2
# 99998   22                 9                1                  5
# 99999   43                 0                3                  1
#
#        Monthly_Salary  Work_Hours_Per_Week  Projects_Handled  Overtime_Hours  \
# 0              6750.0                   33                32              22
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is the DataFrame you want to plot
plt.figure(figsize=(10, 6))
sns.boxplot(data=df)
plt.title('Box Plot for the DataFrame')
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility if necessary
plt.show()

# %%
corrm = df.corr()
corrm
# Out:
#                             Age  Years_At_Company  Education_Level  \
# Age                    1.000000          0.000078         0.003771
# Years_At_Company       0.000078          1.000000        -0.003247
# Education_Level        0.003771         -0.003247         1.000000
# Performance_Score      0.001598          0.001598         0.006658
# Monthly_Salary         0.002757         -0.000645         0.006055
# Work_Hours_Per_Week   -0.003050          0.002578        -0.000331
# Projects_Handled      -0.001726          0.002963        -0.002420
# Overtime_Hours         0.001875          0.001965         0.002518
# Remote_Work_Frequency -0.004672         -0.002443        -0.000632
# Training_Hours         0.002045          0.002696        -0.002323
# Promotions            -0.002888         -0.002737         0.002001
#
#                        Performance_Score  Monthly_Salary  Work_Hours_Per_Week  \
# Age                             0.001598        0.002757            -0.003050
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20,10))
sns.heatmap(corrm, annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import r2_score
import torch
import torch.nn as nn
import torch.optim as optim

# Check if GPU is available and set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Define features (X) and target (y)
X = df.drop('Performance_Score', axis=1)
y = df['Performance_Score'].values.reshape(-1, 1)

# Standardize the features and target
scaler_X = StandardScaler()
X_scaled = scaler_X.fit_transform(X)

scaler_y = StandardScaler()
y_scaled = scaler_y.fit_transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.25, random_state=42)

# Convert the data to PyTorch tensors and move them to the GPU
X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).to(device)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32).to(device)

# Define the neural network model
class ProductivityNN(nn.Module):
    def __init__(self, input_size):
        super(ProductivityNN, self).__init__()
        self.layer1 = nn.Linear(input_size, 1024)
        self.relu = nn.ReLU()
        self.layer2 = nn.Linear(1024, 512)
        self.layer3 = nn.Linear(512, 256)
        self.layer4 = nn.Linear(256, 128)
        self.layer5 = nn.Linear(128, 64)
        self.layer6 = nn.Linear(64, 32)
        self.layer7 = nn.Linear(32, 16)
        self.outlayer = nn.Linear(16, 1)

    def forward(self, x):
        x = self.relu(self.layer1(x))
        x = self.relu(self.layer2(x))
        x = self.relu(self.layer3(x))
        x = self.relu(self.layer4(x))
        x = self.relu(self.layer5(x))
        x = self.relu(self.layer6(x))
        x = self.relu(self.layer7(x))
        x = self.outlayer(x)
        return x

# Instantiate the model, define the loss function and optimizer
input_size = X_train.shape[1]
model = ProductivityNN(input_size).to(device)  # Move the model to GPU
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Train the model
num_epochs = 5400
for epoch in range(num_epochs):
    model.train()
    optimizer.zero_grad()
    outputs = model(X_train_tensor)
    loss = criterion(outputs, y_train_tensor)
    loss.backward()
    optimizer.step()

    if (epoch+1) % 100 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

# Evaluate the model
model.eval()
with torch.no_grad():
    predictions = model(X_test_tensor)
    train_outputs = model(X_train_tensor)
    test_outputs = model(X_test_tensor)

# Convert predictions back to original scale
train_r2_score = r2_score(y_train_tensor.cpu(), train_outputs.cpu())  # Move data back to CPU for calculation
test_r2_score = r2_score(y_test_tensor.cpu(), test_outputs.cpu())

# Show the R2 scores
print(f'Train R2 Score: {train_r2_score * 100:.2f}')
print(f'Test R2 Score: {test_r2_score * 100:.2f}')
# Out:
# Using device: cuda
# Epoch [100/5400], Loss: 0.6692
# Epoch [200/5400], Loss: 0.5790
# Epoch [300/5400], Loss: 0.3881
# Epoch [400/5400], Loss: 0.3294
# Epoch [500/5400], Loss: 0.5161
# Epoch [600/5400], Loss: 0.3375
# Epoch [700/5400], Loss: 0.2939
# Epoch [800/5400], Loss: 0.2737
# Epoch [900/5400], Loss: 0.2983
# Epoch [1000/5400], Loss: 0.2650
# Epoch [1100/5400], Loss: 0.2408
# Epoch [1200/5400], Loss: 0.2124
# Epoch [1300/5400], Loss: 0.1851
# Epoch [1400/5400], Loss: 0.1843
# Epoch [1500/5400], Loss: 0.1562
# Epoch [1600/5400], Loss: 0.1510
# Epoch [1700/5400], Loss: 0.1421
# Epoch [1800/5400], Loss: 0.1099
# Epoch [1900/5400], Loss: 0.1107
# Epoch [2000/5400], Loss: 0.0870
# Epoch [2100/5400], Loss: 0.0700
# Epoch [2200/5400], Loss: 0.0719
# Epoch [2300/5400], Loss: 0.0586
# Epoch [2400/5400], Loss: 0.1271
# Epoch [2500/5400], Loss: 0.0611
# Epoch [2600/5400], Loss: 0.0613
# Epoch [2700/5400], Loss: 0.0649
# Epoch [2800/5400], Loss: 0.0763
# Epoch [2900/5400], Loss: 0.0549
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import  train_test_split

X = df.drop('Performance_Score',axis=1)
y = df['Performance_Score'].values.reshape(-1,1)

scaler1 = StandardScaler()
X_scaled = scaler1.fit_transform(X)
y_scaled = scaler1.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X_scaled,y_scaled,test_size=0.27,random_state=27)

model = DecisionTreeRegressor()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

MSE = mean_squared_error(y_test,y_pred)
R_2_Score = r2_score(y_test,y_pred)

print(MSE)
print(f'r2_score: {R_2_Score}')
